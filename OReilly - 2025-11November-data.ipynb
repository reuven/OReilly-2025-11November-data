# %% [markdown]
# # Agenda
#
# 1. Getting started and series
#     - Why Python?
#     - What is Pandas?
#     - Pandas series -- defining and working with them
#     - Broadcasting
#     - Boolean/mask indexes
#     - Indexes
#     - Dtypes
# 3. Data frames
# 4. Analyzing data
